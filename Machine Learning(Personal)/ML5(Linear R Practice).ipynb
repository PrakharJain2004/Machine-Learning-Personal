# %%
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn import linear_model

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 841F-DC1C
#
#  Directory of C:\Users\Prakhar Jain\OneDrive\Desktop\Machine-Learning-Personal\Machine Learning(Personal)
#
# 04-03-2024  01:06    <DIR>          .
# 03-03-2024  23:48    <DIR>          ..
# 05-12-2023  21:56    <DIR>          .idea
# 04-03-2024  00:15    <DIR>          .ipynb_checkpoints
# 11-11-2023  14:54               226 Data.csv
# 13-11-2023  23:09                61 Data2.csv
# 13-11-2023  23:08                 0 Data2.txt
# 14-11-2023  01:00               120 Data3.csv
# 14-11-2023  23:11               247 Data4.csv
# 04-03-2024  00:22           229,871 death.csv
# 14-11-2023  01:16            13,662 M3(Linear Regression with Multiple Variables).ipynb
# 03-12-2023  21:15            17,166 ML1(Data Preprocessing).ipynb
# 04-12-2023  22:21            50,414 ML2(Linear Regression with one Variable).ipynb
# 14-11-2023  23:27            58,109 ML4(Polynomial Regression) .ipynb
# 04-03-2024  01:06            59,818 ML5(Linear R Practice).ipynb
# 04-12-2023  22:14    <DIR>          venv
#               11 File(s)        429,694 bytes
#                5 Dir(s)  38,293,786,624 bytes free

# %%
data = pd.read_csv('death.csv')

# %%
data.head()
# Out:
#                         County   FIPS Met Objective of 45.5? (1)  \
# 0                United States      0                         No
# 1       Perry County, Kentucky  21193                         No
# 2      Powell County, Kentucky  21197                         No
# 3  North Slope Borough, Alaska   2185                         No
# 4      Owsley County, Kentucky  21189                         No
#
#   Age-Adjusted Death Rate Lower 95% Confidence Interval for Death Rate  \
# 0                      46                                         45.9
# 1                   125.6                                        108.9
# 2                   125.3                                        100.2
# 3                   124.9                                           73
# 4                   118.5                                         83.1
#
#   Upper 95% Confidence Interval for Death Rate Average Deaths per Year  \
# 0                                         46.1                 157,376
# 1                                        144.2                      43
# 2                                        155.1                      18
# 3                                        194.7                       5
# 4                                        165.5                       8
#
#   Recent Trend (2) Recent 5-Year Trend (2) in Death Rates  \
# 0          falling                                   -2.4
# 1           stable                                   -0.6
# 2           stable                                    1.7
# 3               **                                     **
# 4           stable                                    2.2
#
#   Lower 95% Confidence Interval for Trend  \
# 0                                    -2.6
# 1                                    -2.7
# 2                                       0
# 3                                      **
# 4                                    -0.4
#
#   Upper 95% Confidence Interval for Trend
# 0                                    -2.2
# 1                                     1.6
# 2                                     3.4
# 3                                      **
# 4                                     4.8

# %% [markdown]
# # Data Cleaning

# %%
data2 = data.drop(data.index[0])

# %%
data2
# Out:
#                                             County   FIPS  \
# 1                           Perry County, Kentucky  21193
# 2                          Powell County, Kentucky  21197
# 3                      North Slope Borough, Alaska   2185
# 4                          Owsley County, Kentucky  21189
# 5                            Union County, Florida  12125
# ...                                            ...    ...
# 3136  Yakutat City and Borough, Alaska<sup>3</sup>   2282
# 3137             Yukon-Koyukuk Census Area, Alaska   2290
# 3138                          Zapata County, Texas  48505
# 3139                          Zavala County, Texas  48507
# 3140                  Ziebach County, South Dakota  46137
#
#      Met Objective of 45.5? (1) Age-Adjusted Death Rate  \
# 1                            No                   125.6
# 2                            No                   125.3
# 3                            No                   124.9
# 4                            No                   118.5
# 5                            No                   113.5
# ...                         ...                     ...
# 3136                          *                       *
# 3137                          *                       *
# 3138                          *                       *
# 3139                          *                       *
# 3140                          *                       *
#
#      Lower 95% Confidence Interval for Death Rate  \
# 1                                           108.9
# 2                                           100.2
# 3                                              73
# 4                                            83.1
# 5                                            89.9
# ...                                           ...
# 3136                                            *
# 3137                                            *
# 3138                                            *
# 3139                                            *
# 3140                                            *
#
#      Upper 95% Confidence Interval for Death Rate Average Deaths per Year  \
# 1                                           144.2                      43
# 2                                           155.1                      18
# 3                                           194.7                       5
# 4                                           165.5                       8
# 5                                           141.4                      19
# ...                                           ...                     ...
# 3136                                            *                       *
# 3137                                            *                       *
# 3138                                            *                       *
# 3139                                            *                       *
# 3140                                            *                       *
#
#      Recent Trend (2) Recent 5-Year Trend (2) in Death Rates  \
# 1              stable                                   -0.6
# 2              stable                                    1.7
# 3                  **                                     **
# 4              stable                                    2.2
# 5             falling                                   -2.2
# ...               ...                                    ...
# 3136               **                                     **
# 3137               **                                     **
# 3138                *                                      *
# 3139               **                                     **
# 3140               **                                     **
#
#      Lower 95% Confidence Interval for Trend  \
# 1                                       -2.7
# 2                                          0
# 3                                         **
# 4                                       -0.4
# 5                                       -4.3
# ...                                      ...
# 3136                                      **
# 3137                                      **
# 3138                                       *
# 3139                                      **
# 3140                                      **
#
#      Upper 95% Confidence Interval for Trend
# 1                                        1.6
# 2                                        3.4
# 3                                         **
# 4                                        4.8
# 5                                          0
# ...                                      ...
# 3136                                      **
# 3137                                      **
# 3138                                       *
# 3139                                      **
# 3140                                      **
#
# [3140 rows x 11 columns]

# %%
data2.replace(['*', '**'],"*", inplace=True)

# %%
data2
# Out:
#                                             County   FIPS  \
# 1                           Perry County, Kentucky  21193
# 2                          Powell County, Kentucky  21197
# 3                      North Slope Borough, Alaska   2185
# 4                          Owsley County, Kentucky  21189
# 5                            Union County, Florida  12125
# ...                                            ...    ...
# 3136  Yakutat City and Borough, Alaska<sup>3</sup>   2282
# 3137             Yukon-Koyukuk Census Area, Alaska   2290
# 3138                          Zapata County, Texas  48505
# 3139                          Zavala County, Texas  48507
# 3140                  Ziebach County, South Dakota  46137
#
#      Met Objective of 45.5? (1) Age-Adjusted Death Rate  \
# 1                            No                   125.6
# 2                            No                   125.3
# 3                            No                   124.9
# 4                            No                   118.5
# 5                            No                   113.5
# ...                         ...                     ...
# 3136                          *                       *
# 3137                          *                       *
# 3138                          *                       *
# 3139                          *                       *
# 3140                          *                       *
#
#      Lower 95% Confidence Interval for Death Rate  \
# 1                                           108.9
# 2                                           100.2
# 3                                              73
# 4                                            83.1
# 5                                            89.9
# ...                                           ...
# 3136                                            *
# 3137                                            *
# 3138                                            *
# 3139                                            *
# 3140                                            *
#
#      Upper 95% Confidence Interval for Death Rate Average Deaths per Year  \
# 1                                           144.2                      43
# 2                                           155.1                      18
# 3                                           194.7                       5
# 4                                           165.5                       8
# 5                                           141.4                      19
# ...                                           ...                     ...
# 3136                                            *                       *
# 3137                                            *                       *
# 3138                                            *                       *
# 3139                                            *                       *
# 3140                                            *                       *
#
#      Recent Trend (2) Recent 5-Year Trend (2) in Death Rates  \
# 1              stable                                   -0.6
# 2              stable                                    1.7
# 3                   *                                      *
# 4              stable                                    2.2
# 5             falling                                   -2.2
# ...               ...                                    ...
# 3136                *                                      *
# 3137                *                                      *
# 3138                *                                      *
# 3139                *                                      *
# 3140                *                                      *
#
#      Lower 95% Confidence Interval for Trend  \
# 1                                       -2.7
# 2                                          0
# 3                                          *
# 4                                       -0.4
# 5                                       -4.3
# ...                                      ...
# 3136                                       *
# 3137                                       *
# 3138                                       *
# 3139                                       *
# 3140                                       *
#
#      Upper 95% Confidence Interval for Trend
# 1                                        1.6
# 2                                        3.4
# 3                                          *
# 4                                        4.8
# 5                                          0
# ...                                      ...
# 3136                                       *
# 3137                                       *
# 3138                                       *
# 3139                                       *
# 3140                                       *
#
# [3140 rows x 11 columns]

# %%
data2.replace("*", pd.NA, inplace=True)

# %%
data2
# Out:
#                                             County   FIPS  \
# 1                           Perry County, Kentucky  21193
# 2                          Powell County, Kentucky  21197
# 3                      North Slope Borough, Alaska   2185
# 4                          Owsley County, Kentucky  21189
# 5                            Union County, Florida  12125
# ...                                            ...    ...
# 3136  Yakutat City and Borough, Alaska<sup>3</sup>   2282
# 3137             Yukon-Koyukuk Census Area, Alaska   2290
# 3138                          Zapata County, Texas  48505
# 3139                          Zavala County, Texas  48507
# 3140                  Ziebach County, South Dakota  46137
#
#      Met Objective of 45.5? (1) Age-Adjusted Death Rate  \
# 1                            No                   125.6
# 2                            No                   125.3
# 3                            No                   124.9
# 4                            No                   118.5
# 5                            No                   113.5
# ...                         ...                     ...
# 3136                        NaN                     NaN
# 3137                        NaN                     NaN
# 3138                        NaN                     NaN
# 3139                        NaN                     NaN
# 3140                        NaN                     NaN
#
#      Lower 95% Confidence Interval for Death Rate  \
# 1                                           108.9
# 2                                           100.2
# 3                                              73
# 4                                            83.1
# 5                                            89.9
# ...                                           ...
# 3136                                          NaN
# 3137                                          NaN
# 3138                                          NaN
# 3139                                          NaN
# 3140                                          NaN
#
#      Upper 95% Confidence Interval for Death Rate Average Deaths per Year  \
# 1                                           144.2                      43
# 2                                           155.1                      18
# 3                                           194.7                       5
# 4                                           165.5                       8
# 5                                           141.4                      19
# ...                                           ...                     ...
# 3136                                          NaN                     NaN
# 3137                                          NaN                     NaN
# 3138                                          NaN                     NaN
# 3139                                          NaN                     NaN
# 3140                                          NaN                     NaN
#
#      Recent Trend (2) Recent 5-Year Trend (2) in Death Rates  \
# 1              stable                                   -0.6
# 2              stable                                    1.7
# 3                <NA>                                   <NA>
# 4              stable                                    2.2
# 5             falling                                   -2.2
# ...               ...                                    ...
# 3136              NaN                                    NaN
# 3137              NaN                                    NaN
# 3138              NaN                                    NaN
# 3139              NaN                                    NaN
# 3140              NaN                                    NaN
#
#      Lower 95% Confidence Interval for Trend  \
# 1                                       -2.7
# 2                                          0
# 3                                       <NA>
# 4                                       -0.4
# 5                                       -4.3
# ...                                      ...
# 3136                                     NaN
# 3137                                     NaN
# 3138                                     NaN
# 3139                                     NaN
# 3140                                     NaN
#
#      Upper 95% Confidence Interval for Trend
# 1                                        1.6
# 2                                        3.4
# 3                                       <NA>
# 4                                        4.8
# 5                                          0
# ...                                      ...
# 3136                                     NaN
# 3137                                     NaN
# 3138                                     NaN
# 3139                                     NaN
# 3140                                     NaN
#
# [3140 rows x 11 columns]

# %%
data2.dropna(subset=['Met Objective of 45.5? (1)'], inplace=True)

# %%
data2
# Out:
#                            County   FIPS Met Objective of 45.5? (1)  \
# 1          Perry County, Kentucky  21193                         No
# 2         Powell County, Kentucky  21197                         No
# 3     North Slope Borough, Alaska   2185                         No
# 4         Owsley County, Kentucky  21189                         No
# 5           Union County, Florida  12125                         No
# ...                           ...    ...                        ...
# 2808       Eagle County, Colorado   8037                        Yes
# 2809          Summit County, Utah  49043                        Yes
# 2810            Utah County, Utah  49049                        Yes
# 2811  McKinley County, New Mexico  35031                        Yes
# 2812           Cache County, Utah  49005                        Yes
#
#      Age-Adjusted Death Rate Lower 95% Confidence Interval for Death Rate  \
# 1                      125.6                                        108.9
# 2                      125.3                                        100.2
# 3                      124.9                                           73
# 4                      118.5                                         83.1
# 5                      113.5                                         89.9
# ...                      ...                                          ...
# 2808                    14.9                                          8.7
# 2809                    14.4                                          8.2
# 2810                    12.4                                         10.7
# 2811                    11.6                                            8
# 2812                     9.2                                          6.4
#
#      Upper 95% Confidence Interval for Death Rate Average Deaths per Year  \
# 1                                           144.2                      43
# 2                                           155.1                      18
# 3                                           194.7                       5
# 4                                           165.5                       8
# 5                                           141.4                      19
# ...                                           ...                     ...
# 2808                                         23.6                       5
# 2809                                         23.2                       4
# 2810                                         14.4                      37
# 2811                                         16.2                       7
# 2812                                         12.8                       7
#
#      Recent Trend (2) Recent 5-Year Trend (2) in Death Rates  \
# 1              stable                                   -0.6
# 2              stable                                    1.7
# 3                <NA>                                   <NA>
# 4              stable                                    2.2
# 5             falling                                   -2.2
# ...               ...                                    ...
# 2808          falling                                   -4.9
# 2809             <NA>                                   <NA>
# 2810          falling                                   -2.8
# 2811          falling                                   -3.2
# 2812           stable                                   -0.7
#
#      Lower 95% Confidence Interval for Trend  \
# 1                                       -2.7
# 2                                          0
# 3                                       <NA>
# 4                                       -0.4
# 5                                       -4.3
# ...                                      ...
# 2808                                    -9.3
# 2809                                    <NA>
# 2810                                    -3.9
# 2811                                    -5.7
# 2812                                      -3
#
#      Upper 95% Confidence Interval for Trend
# 1                                        1.6
# 2                                        3.4
# 3                                       <NA>
# 4                                        4.8
# 5                                          0
# ...                                      ...
# 2808                                    -0.3
# 2809                                    <NA>
# 2810                                    -1.8
# 2811                                    -0.7
# 2812                                     1.6
#
# [2812 rows x 11 columns]

# %%
data2['Recent Trend (2)'].value_counts()
# Out:
# Recent Trend (2)
# stable     1796
# falling     866
# rising       31
# Name: count, dtype: int64

# %%
na_rows = data2[data2['Recent Trend (2)'].isna()]

# %%
na_rows
# Out:
#                            County   FIPS Met Objective of 45.5? (1)  \
# 3     North Slope Borough, Alaska   2185                         No
# 18       Nome Census Area, Alaska   2180                         No
# 36            Upton County, Texas  48461                         No
# 44        Quitman County, Georgia  13239                         No
# 85          Knox County, Missouri  29103                         No
# ...                           ...    ...                        ...
# 2788         Wasatch County, Utah  49051                        Yes
# 2791   Archuleta County, Colorado   8007                        Yes
# 2797      Summit County, Colorado   8117                        Yes
# 2800  Rio Grande County, Colorado   8105                        Yes
# 2809          Summit County, Utah  49043                        Yes
#
#      Age-Adjusted Death Rate Lower 95% Confidence Interval for Death Rate  \
# 3                      124.9                                           73
# 18                      96.1                                         61.4
# 36                      89.1                                         51.9
# 44                      87.2                                         50.3
# 85                      81.5                                         52.5
# ...                      ...                                          ...
# 2788                    23.1                                         13.6
# 2791                    22.7                                         13.5
# 2797                    21.6                                         10.5
# 2800                      21                                         11.9
# 2809                    14.4                                          8.2
#
#      Upper 95% Confidence Interval for Death Rate Average Deaths per Year  \
# 3                                           194.7                       5
# 18                                          141.6                       6
# 36                                          144.1                       3
# 44                                          146.9                       4
# 85                                          123.2                       5
# ...                                           ...                     ...
# 2788                                         36.2                       4
# 2791                                         36.7                       4
# 2797                                         37.8                       3
# 2800                                         34.9                       3
# 2809                                         23.2                       4
#
#      Recent Trend (2) Recent 5-Year Trend (2) in Death Rates  \
# 3                 NaN                                    NaN
# 18                NaN                                    NaN
# 36                NaN                                    NaN
# 44                NaN                                    NaN
# 85                NaN                                    NaN
# ...               ...                                    ...
# 2788              NaN                                    NaN
# 2791              NaN                                    NaN
# 2797              NaN                                    NaN
# 2800              NaN                                    NaN
# 2809              NaN                                    NaN
#
#      Lower 95% Confidence Interval for Trend  \
# 3                                        NaN
# 18                                       NaN
# 36                                       NaN
# 44                                       NaN
# 85                                       NaN
# ...                                      ...
# 2788                                     NaN
# 2791                                     NaN
# 2797                                     NaN
# 2800                                     NaN
# 2809                                     NaN
#
#      Upper 95% Confidence Interval for Trend
# 3                                        NaN
# 18                                       NaN
# 36                                       NaN
# 44                                       NaN
# 85                                       NaN
# ...                                      ...
# 2788                                     NaN
# 2791                                     NaN
# 2797                                     NaN
# 2800                                     NaN
# 2809                                     NaN
#
# [119 rows x 11 columns]

# %%
data2.dropna(subset=['Recent Trend (2)'], inplace=True)

# %%
data2
# Out:
#                              County   FIPS Met Objective of 45.5? (1)  \
# 1            Perry County, Kentucky  21193                         No
# 2           Powell County, Kentucky  21197                         No
# 4           Owsley County, Kentucky  21189                         No
# 5             Union County, Florida  12125                         No
# 6         McCreary County, Kentucky  21147                         No
# ...                             ...    ...                        ...
# 2807  Los Alamos County, New Mexico  35028                        Yes
# 2808         Eagle County, Colorado   8037                        Yes
# 2810              Utah County, Utah  49049                        Yes
# 2811    McKinley County, New Mexico  35031                        Yes
# 2812             Cache County, Utah  49005                        Yes
#
#      Age-Adjusted Death Rate Lower 95% Confidence Interval for Death Rate  \
# 1                      125.6                                        108.9
# 2                      125.3                                        100.2
# 4                      118.5                                         83.1
# 5                      113.5                                         89.9
# 6                      111.1                                         90.6
# ...                      ...                                          ...
# 2807                    15.8                                          9.4
# 2808                    14.9                                          8.7
# 2810                    12.4                                         10.7
# 2811                    11.6                                            8
# 2812                     9.2                                          6.4
#
#      Upper 95% Confidence Interval for Death Rate Average Deaths per Year  \
# 1                                           144.2                      43
# 2                                           155.1                      18
# 4                                           165.5                       8
# 5                                           141.4                      19
# 6                                           134.9                      22
# ...                                           ...                     ...
# 2807                                         25.4                       4
# 2808                                         23.6                       5
# 2810                                         14.4                      37
# 2811                                         16.2                       7
# 2812                                         12.8                       7
#
#      Recent Trend (2) Recent 5-Year Trend (2) in Death Rates  \
# 1              stable                                   -0.6
# 2              stable                                    1.7
# 4              stable                                    2.2
# 5             falling                                   -2.2
# 6              rising                                   22.9
# ...               ...                                    ...
# 2807           stable                                   -2.9
# 2808          falling                                   -4.9
# 2810          falling                                   -2.8
# 2811          falling                                   -3.2
# 2812           stable                                   -0.7
#
#      Lower 95% Confidence Interval for Trend  \
# 1                                       -2.7
# 2                                          0
# 4                                       -0.4
# 5                                       -4.3
# 6                                        6.9
# ...                                      ...
# 2807                                    -5.8
# 2808                                    -9.3
# 2810                                    -3.9
# 2811                                    -5.7
# 2812                                      -3
#
#      Upper 95% Confidence Interval for Trend
# 1                                        1.6
# 2                                        3.4
# 4                                        4.8
# 5                                          0
# 6                                       41.4
# ...                                      ...
# 2807                                       0
# 2808                                    -0.3
# 2810                                    -1.8
# 2811                                    -0.7
# 2812                                     1.6
#
# [2693 rows x 11 columns]

# %%
data2 = data2.reset_index(drop=True)

# %%
data2
# Out:
#                              County   FIPS Met Objective of 45.5? (1)  \
# 0            Perry County, Kentucky  21193                         No
# 1           Powell County, Kentucky  21197                         No
# 2           Owsley County, Kentucky  21189                         No
# 3             Union County, Florida  12125                         No
# 4         McCreary County, Kentucky  21147                         No
# ...                             ...    ...                        ...
# 2688  Los Alamos County, New Mexico  35028                        Yes
# 2689         Eagle County, Colorado   8037                        Yes
# 2690              Utah County, Utah  49049                        Yes
# 2691    McKinley County, New Mexico  35031                        Yes
# 2692             Cache County, Utah  49005                        Yes
#
#      Age-Adjusted Death Rate Lower 95% Confidence Interval for Death Rate  \
# 0                      125.6                                        108.9
# 1                      125.3                                        100.2
# 2                      118.5                                         83.1
# 3                      113.5                                         89.9
# 4                      111.1                                         90.6
# ...                      ...                                          ...
# 2688                    15.8                                          9.4
# 2689                    14.9                                          8.7
# 2690                    12.4                                         10.7
# 2691                    11.6                                            8
# 2692                     9.2                                          6.4
#
#      Upper 95% Confidence Interval for Death Rate Average Deaths per Year  \
# 0                                           144.2                      43
# 1                                           155.1                      18
# 2                                           165.5                       8
# 3                                           141.4                      19
# 4                                           134.9                      22
# ...                                           ...                     ...
# 2688                                         25.4                       4
# 2689                                         23.6                       5
# 2690                                         14.4                      37
# 2691                                         16.2                       7
# 2692                                         12.8                       7
#
#      Recent Trend (2) Recent 5-Year Trend (2) in Death Rates  \
# 0              stable                                   -0.6
# 1              stable                                    1.7
# 2              stable                                    2.2
# 3             falling                                   -2.2
# 4              rising                                   22.9
# ...               ...                                    ...
# 2688           stable                                   -2.9
# 2689          falling                                   -4.9
# 2690          falling                                   -2.8
# 2691          falling                                   -3.2
# 2692           stable                                   -0.7
#
#      Lower 95% Confidence Interval for Trend  \
# 0                                       -2.7
# 1                                          0
# 2                                       -0.4
# 3                                       -4.3
# 4                                        6.9
# ...                                      ...
# 2688                                    -5.8
# 2689                                    -9.3
# 2690                                    -3.9
# 2691                                    -5.7
# 2692                                      -3
#
#      Upper 95% Confidence Interval for Trend
# 0                                        1.6
# 1                                        3.4
# 2                                        4.8
# 3                                          0
# 4                                       41.4
# ...                                      ...
# 2688                                       0
# 2689                                    -0.3
# 2690                                    -1.8
# 2691                                    -0.7
# 2692                                     1.6
#
# [2693 rows x 11 columns]
